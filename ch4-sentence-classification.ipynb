# %%
from itertools import chain
from typing import Dict
 
import numpy as np
import torch
import torch.optim as optim
from allennlp.data.data_loaders import MultiProcessDataLoader
from allennlp.data.samplers import BucketBatchSampler
from allennlp.data.vocabulary import Vocabulary
from allennlp.models import Model
from allennlp.modules.seq2vec_encoders import Seq2VecEncoder, PytorchSeq2VecWrapper
from allennlp.modules.text_field_embedders import TextFieldEmbedder, BasicTextFieldEmbedder
from allennlp.modules.token_embedders import Embedding
from allennlp.nn.util import get_text_field_mask
from allennlp.training.metrics import CategoricalAccuracy, F1Measure
from allennlp.training import GradientDescentTrainer
from allennlp_models.classification.dataset_readers.stanford_sentiment_tree_bank import StanfordSentimentTreeBankDatasetReader
# Out:
# /usr/local/lib/python3.9/site-packages/allennlp/tango/__init__.py:17: UserWarning: AllenNLP Tango is an experimental API and parts of it might change or disappear every time we release a new version.
#   warnings.warn(

# %%
reader = StanfordSentimentTreeBankDatasetReader()
 
train_dataset = reader.read('data/train.txt')
dev_dataset = reader.read('data/dev.txt')
 
for inst in chain(train_dataset, dev_dataset):
    print(inst)
# Out:
# Instance with fields:
#  	 tokens: TextField of length 36 with text:
#  		[The, Rock, is, destined, to, be, the, 21st, Century, 's, new, ``, Conan, '', and, that, he, 's,
# 		going, to, make, a, splash, even, greater, than, Arnold, Schwarzenegger, ,, Jean-Claud, Van, Damme,
# 		or, Steven, Segal, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 37 with text:
#  		[The, gorgeously, elaborate, continuation, of, ``, The, Lord, of, the, Rings, '', trilogy, is, so,
# 		huge, that, a, column, of, words, can, not, adequately, describe, co-writer\/director, Peter,
# 		Jackson, 's, expanded, vision, of, J.R.R., Tolkien, 's, Middle-earth, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 39 with text:
#  		[Singer\/composer, Bryan, Adams, contributes, a, slew, of, songs, --, a, few, potential, hits, ,, a,
# 		few, more, simply, intrusive, to, the, story, --, but, the, whole, package, certainly, captures,
# 		the, intended, ,, er, ,, spirit, of, the, piece, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 19 with text:
#  		[You, 'd, think, by, now, America, would, have, had, enough, of, plucky, British, eccentrics, with,
# 		hearts, of, gold, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 8 with text:
#  		[Yet, the, act, is, still, charming, here, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 32 with text:
#  		[Whether, or, not, you, 're, enlightened, by, any, of, Derrida, 's, lectures, on, ``, the, other,
# 		'', and, ``, the, self, ,, '', Derrida, is, an, undeniably, fascinating, and, playful, fellow, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 22 with text:
#  		[Just, the, labour, involved, in, creating, the, layered, richness, of, the, imagery, in, this,
# 		chiaroscuro, of, madness, and, light, is, astonishing, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 18 with text:
#  		[Part, of, the, charm, of, Satin, Rouge, is, that, it, avoids, the, obvious, with, humour, and,
# 		lightness, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 9 with text:
#  		[a, screenplay, more, ingeniously, constructed, than, ``, Memento, '']
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 7 with text:
#  		[``, Extreme, Ops, '', exceeds, expectations, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 18 with text:
#  		[Good, fun, ,, good, action, ,, good, acting, ,, good, dialogue, ,, good, pace, ,, good,
# 		cinematography, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 24 with text:
#  		[You, Should, Pay, Nine, Bucks, for, This, :, Because, you, can, hear, about, suffering, Afghan,
# 		refugees, on, the, news, and, still, be, unaffected, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 7 with text:
#  		[Dramas, like, this, make, it, human, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 27 with text:
#  		[A, thunderous, ride, at, first, ,, quiet, cadences, of, pure, finesse, are, few, and, far, between,
# 		;, their, shortage, dilutes, the, potency, of, otherwise, respectable, action, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 15 with text:
#  		[Still, ,, this, flick, is, fun, ,, and, host, to, some, truly, excellent, sequences, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 23 with text:
#  		[Australian, actor\/director, John, Polson, and, award-winning, English, cinematographer, Giles,
# 		Nuttgens, make, a, terrific, effort, at, disguising, the, obvious, with, energy, and, innovation, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 24 with text:
#  		[You, walk, out, of, The, Good, Girl, with, mixed, emotions, --, disapproval, of, Justine, combined,
# 		with, a, tinge, of, understanding, for, her, actions, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 19 with text:
#  		[Post, 9\/11, the, philosophical, message, of, ``, Personal, Freedom, First, '', might, not, be, as,
# 		palatable, as, intended, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 7 with text:
#  		[Absorbing, character, study, by, André, Turpin, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 15 with text:
#  		[If, you, love, reading, and\/or, poetry, ,, then, by, all, means, check, it, out, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 6 with text:
#  		[You, 'll, probably, love, it, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 17 with text:
#  		[``, Frailty, '', has, been, written, so, well, ,, that, even, a, simple, ``, Goddammit, !, '']
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 10 with text:
#  		[near, the, end, takes, on, a, whole, other, meaning, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 19 with text:
#  		[Grenier, is, terrific, ,, bringing, an, unforced, ,, rapid-fire, delivery, to, Toback, 's,
# 		Heidegger, -, and, Nietzsche-referencing, dialogue, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 25 with text:
#  		[The, Sundance, Film, Festival, has, become, so, buzz-obsessed, that, fans, and, producers, descend,
# 		upon, Utah, each, January, to, ferret, out, The, Next, Great, Thing, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 25 with text:
#  		[`, Tadpole, ', was, one, of, the, films, so, declared, this, year, ,, but, it, 's, really, more,
# 		of, The, Next, Pretty, Good, Thing, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 5 with text:
#  		[The, actors, are, fantastic, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 12 with text:
#  		[They, are, what, makes, it, worth, the, trip, to, the, theatre, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 29 with text:
#  		[-LRB-, Taymor, -RRB-, utilizes, the, idea, of, making, Kahlo, 's, art, a, living, ,, breathing,
# 		part, of, the, movie, ,, often, catapulting, the, artist, into, her, own, work, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 7 with text:
#  		[This, is, n't, a, new, idea, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 15 with text:
#  		[It, 's, been, done, before, but, never, so, vividly, or, with, so, much, passion, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 39 with text:
#  		[-LRB-, ``, Take, Care, of, My, Cat, '', -RRB-, is, an, honestly, nice, little, film, that, takes,
# 		us, on, an, examination, of, young, adult, life, in, urban, South, Korea, through, the, hearts, and,
# 		minds, of, the, five, principals, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 15 with text:
#  		[It, 's, not, life-affirming, --, its, vulgar, and, mean, ,, but, I, liked, it, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 15 with text:
#  		[What, ``, Empire, '', lacks, in, depth, it, makes, up, for, with, its, heart, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 16 with text:
#  		[Light, ,, silly, ,, photographed, with, colour, and, depth, ,, and, rather, a, good, time, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 30 with text:
#  		[But, tongue-in-cheek, preposterousness, has, always, been, part, of, For, the, most, part, Wilde,
# 		's, droll, whimsy, helps, ``, Being, Earnest, '', overcome, its, weaknesses, and, Parker, 's,
# 		creative, interference, ...]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 16 with text:
#  		[Much, of, the, movie, 's, charm, lies, in, the, utter, cuteness, of, Stuart, and, Margolo, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 7 with text:
#  		[Their, computer-animated, faces, are, very, expressive, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 33 with text:
#  		[The, path, Ice, Age, follows, most, closely, ,, though, ,, is, the, one, established, by, Warner,
# 		Bros., giant, Chuck, Jones, ,, who, died, a, matter, of, weeks, before, the, movie, 's, release, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 51 with text:
#  		[..., spiced, with, humor, -LRB-, ', I, speak, fluent, flatula, ,, ', advises, Denlopp, after, a,
# 		rather, ,, er, ,, bubbly, exchange, with, an, alien, deckhand, -RRB-, and, witty, updatings, -LRB-,
# 		Silver, 's, parrot, has, been, replaced, with, Morph, ,, a, cute, alien, creature, who, mimics,
# 		everyone, and, everything, around, -RRB-]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 10 with text:
#  		[There, 's, an, energy, to, Y, Tu, Mamá, También, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 15 with text:
#  		[Much, of, it, comes, from, the, brave, ,, uninhibited, performances, by, its, lead, actors, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 19 with text:
#  		[``, 13, Conversations, '', holds, its, goodwill, close, ,, but, is, relatively, slow, to, come, to,
# 		the, point, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 18 with text:
#  		[``, Auto, Focus, '', works, as, an, unusual, biopic, and, document, of, male, swingers, in, the,
# 		Playboy, era]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 26 with text:
#  		[If, Mr., Zhang, 's, subject, matter, is, ,, to, some, degree, at, least, ,, quintessentially,
# 		American, ,, his, approach, to, storytelling, might, be, called, Iranian, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 38 with text:
#  		[..., a, sour, little, movie, at, its, core, ;, an, exploration, of, the, emptiness, that, underlay,
# 		the, relentless, gaiety, of, the, 1920, 's, ..., The, film, 's, ending, has, a, ``, What, was, it,
# 		all, for, ?, '']
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 0 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 20 with text:
#  		[feeling, to, it, ,, but, like, the, 1920, 's, ,, the, trip, there, is, a, great, deal, of, fun, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 17 with text:
#  		[``, Cremaster, 3, '', should, come, with, the, warning, ``, For, serious, film, buffs, only, !, '']
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 21 with text:
#  		[Made, me, unintentionally, famous, --, as, the, queasy-stomached, critic, who, staggered, from,
# 		the, theater, and, blacked, out, in, the, lobby, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 20 with text:
#  		[But, believe, it, or, not, ,, it, 's, one, of, the, most, beautiful, ,, evocative, works, I, 've,
# 		seen, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 26 with text:
#  		[García, Bernal, and, Talancón, are, an, immensely, appealing, couple, ,, and, even, though, their,
# 		story, is, predictable, ,, you, 'll, want, things, to, work, out, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 30 with text:
#  		[..., a, spoof, comedy, that, carries, its, share, of, laughs, --, sometimes, a, chuckle, ,,
# 		sometimes, a, guffaw, and, ,, to, my, great, pleasure, ,, the, occasional, belly, laugh, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 50 with text:
#  		[-LRB-, City, -RRB-, reminds, us, how, realistically, nuanced, a, Robert, De, Niro, performance,
# 		can, be, when, he, is, not, more, lucratively, engaged, in, the, shameless, self-caricature, of, `,
# 		Analyze, This, ', -LRB-, 1999, -RRB-, and, `, Analyze, That, ,, ', promised, -LRB-, or, threatened,
# 		-RRB-, for, later, this, year, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 35 with text:
#  		[The, wanton, slipperiness, of, \*, Corpus, and, its, amiable, jerking, and, reshaping, of,
# 		physical, time, and, space, would, make, it, a, great, piece, to, watch, with, kids, and, use, to,
# 		introduce, video, as, art, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 31 with text:
#  		[``, Frailty, '', starts, out, like, a, typical, Bible, killer, story, ,, but, it, turns, out, to,
# 		be, significantly, different, -LRB-, and, better, -RRB-, than, most, films, with, this, theme, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 42 with text:
#  		[For, those, who, pride, themselves, on, sophisticated, ,, discerning, taste, ,, this, might, not,
# 		seem, like, the, proper, cup, of, tea, ,, however, it, is, almost, guaranteed, that, even, the,
# 		stuffiest, cinema, goers, will, laugh, their, \*\*\*, off, for, an, hour-and-a-half, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 52 with text:
#  		[It, cuts, to, the, core, of, what, it, actually, means, to, face, your, fears, ,, to, be, a, girl,
# 		in, a, world, of, boys, ,, to, be, a, boy, truly, in, love, with, a, girl, ,, and, to, ride, the,
# 		big, metaphorical, wave, that, is, life, --, wherever, it, takes, you, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 26 with text:
#  		[A, welcome, relief, from, baseball, movies, that, try, too, hard, to, be, mythic, ,, this, one, is,
# 		a, sweet, and, modest, and, ultimately, winning, story, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 25 with text:
#  		[A, crisp, psychological, drama, -LRB-, and, -RRB-, a, fascinating, little, thriller, that, would,
# 		have, been, perfect, for, an, old, ``, Twilight, Zone, '', episode, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 23 with text:
#  		[It, has, more, than, a, few, moments, that, are, insightful, enough, to, be, fondly, remembered,
# 		in, the, endlessly, challenging, maze, of, moviegoing, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 24 with text:
#  		[Opening, with, some, contrived, banter, ,, cliches, and, some, loose, ends, ,, the, screenplay,
# 		only, comes, into, its, own, in, the, second, half, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 16 with text:
#  		[An, uncluttered, ,, resonant, gem, that, relays, its, universal, points, without, lectures, or,
# 		confrontations, ., ']
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 20 with text:
#  		[-LRB-, The, Cockettes, -RRB-, provides, a, window, into, a, subculture, hell-bent, on, expressing,
# 		itself, in, every, way, imaginable, ., ']
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 15 with text:
#  		[A, smart, ,, steamy, mix, of, road, movie, ,, coming-of-age, story, and, political, satire, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 14 with text:
#  		[The, modern-day, royals, have, nothing, on, these, guys, when, it, comes, to, scandals, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 19 with text:
#  		[It, 's, only, in, fairy, tales, that, princesses, that, are, married, for, political, reason, live,
# 		happily, ever, after, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 14 with text:
#  		[A, terrific, B, movie, --, in, fact, ,, the, best, in, recent, memory, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 13 with text:
#  		[``, Birthday, Girl, '', is, an, actor, 's, movie, first, and, foremost, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 20 with text:
#  		[I, walked, away, from, this, new, version, of, E.T., just, as, I, hoped, I, would, --, with, moist,
# 		eyes, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 24 with text:
#  		[For, devotees, of, French, cinema, ,, Safe, Conduct, is, so, rich, with, period, minutiae, it, 's,
# 		like, dying, and, going, to, celluloid, heaven, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 15 with text:
#  		[What, 's, really, so, appealing, about, the, characters, is, their, resemblance, to, everyday,
# 		children, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 28 with text:
#  		[Shamelessly, resorting, to, pee-related, sight, gags, that, might, even, cause, Tom, Green, a,
# 		grimace, ;, still, ,, Myer, 's, energy, and, the, silliness, of, it, all, eventually, prevail]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 5 with text:
#  		[An, absurdist, spider, web, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 32 with text:
#  		[If, you, 're, as, happy, listening, to, movies, as, you, are, watching, them, ,, and, the, slow,
# 		parade, of, human, frailty, fascinates, you, ,, then, you, 're, at, the, right, film, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 32 with text:
#  		[This, version, moves, beyond, the, original, 's, nostalgia, for, the, communal, film, experiences,
# 		of, yesteryear, to, a, deeper, realization, of, cinema, 's, inability, to, stand, in, for, true, ,,
# 		lived, experience, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 10 with text:
#  		[Some, movies, blend, together, as, they, become, distant, memories, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 23 with text:
#  		[Mention, ``, Solaris, '', five, years, from, now, and, I, 'm, sure, those, who, saw, it, will,
# 		have, an, opinion, to, share, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 10 with text:
#  		[Allen, 's, funniest, and, most, likeable, movie, in, years, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 18 with text:
#  		[It, 's, a, glorious, spectacle, like, those, D.W., Griffith, made, in, the, early, days, of,
# 		silent, film, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 11 with text:
#  		[This, comic, gem, is, as, delightful, as, it, is, derivative, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 37 with text:
#  		[More, timely, than, its, director, could, ever, have, dreamed, ,, this, quietly, lyrical, tale,
# 		probes, the, ambiguous, welcome, extended, by, Iran, to, the, Afghani, refugees, who, streamed,
# 		across, its, borders, ,, desperate, for, work, and, food, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 35 with text:
#  		[The, leaping, story, line, ,, shaped, by, director, Peter, Kosminsky, into, sharp, slivers, and,
# 		cutting, impressions, ,, shows, all, the, signs, of, rich, detail, condensed, into, a, few,
# 		evocative, images, and, striking, character, traits, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 43 with text:
#  		[With, three, excellent, principal, singers, ,, a, youthful, and, good-looking, diva, and, tenor,
# 		and, richly, handsome, locations, ,, it, 's, enough, to, make, you, wish, Jacquot, had, left, well,
# 		enough, alone, and, just, filmed, the, opera, without, all, these, distortions, of, perspective, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 21 with text:
#  		[The, production, has, been, made, with, an, enormous, amount, of, affection, ,, so, we, believe,
# 		these, characters, love, each, other, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 6 with text:
#  		[Certainly, the, performances, are, worthwhile, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 29 with text:
#  		[Winds, up, being, both, revelatory, and, narcissistic, ,, achieving, some, honest, insight, into,
# 		relationships, that, most, high-concept, films, candy-coat, with, pat, storylines, ,, precious,
# 		circumstances, and, beautiful, stars, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 10 with text:
#  		[Watching, these, eccentrics, is, both, inspiring, and, pure, joy, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 6 with text:
#  		[Steven, Spielberg, brings, us, another, masterpiece]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 19 with text:
#  		[Finally, ,, the, French-produced, ``, Read, My, Lips, '', is, a, movie, that, understands,
# 		characters, must, come, first, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 14 with text:
#  		[Ms., Seigner, and, Mr., Serrault, bring, fresh, ,, unforced, naturalism, to, their, characters, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 15 with text:
#  		[Allen, shows, he, can, outgag, any, of, those, young, whippersnappers, making, moving, pictures,
# 		today, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 20 with text:
#  		[A, good, film, with, a, solid, pedigree, both, in, front, of, and, ,, more, specifically, ,,
# 		behind, the, camera, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 41 with text:
#  		[By, no, means, a, slam-dunk, and, sure, to, ultimately, disappoint, the, action, fans, who, will,
# 		be, moved, to, the, edge, of, their, seats, by, the, dynamic, first, act, ,, it, still, comes, off,
# 		as, a, touching, ,, transcendent, love, story, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 27 with text:
#  		[I, encourage, young, and, old, alike, to, go, see, this, unique, and, entertaining, twist, on, the,
# 		classic, whale, 's, tale, --, you, wo, n't, be, sorry, !]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 19 with text:
#  		[A, literary, detective, story, is, still, a, detective, story, and, aficionados, of, the, whodunit,
# 		wo, n't, be, disappointed, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 25 with text:
#  		[High, Crimes, steals, so, freely, from, other, movies, and, combines, enough, disparate, types, of,
# 		films, that, it, ca, n't, help, but, engage, an, audience, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 20 with text:
#  		[If, you, 're, a, fan, of, the, series, you, 'll, love, it, and, probably, want, to, see, it, twice,
# 		.]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 4 with text:
#  		[I, will, be, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 25 with text:
#  		[It, celebrates, the, group, 's, playful, spark, of, nonconformity, ,, glancing, vividly, back, at,
# 		what, Hibiscus, grandly, called, his, `, angels, of, light, ., ']
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 22 with text:
#  		[The, story, ..., is, inspiring, ,, ironic, ,, and, revelatory, of, just, how, ridiculous, and,
# 		money-oriented, the, record, industry, really, is, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 14 with text:
#  		[It, is, also, a, testament, to, the, integrity, and, vision, of, the, band, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 28 with text:
#  		[Laced, with, liberal, doses, of, dark, humor, ,, gorgeous, exterior, photography, ,, and, a,
# 		stable-full, of, solid, performances, ,, No, Such, Thing, is, a, fascinating, little, tale, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 35 with text:
#  		[Huppert, 's, show, to, steal, and, she, makes, a, meal, of, it, ,, channeling, Kathy, Baker, 's,
# 		creepy, turn, as, the, repressed, mother, on, Boston, Public, just, as, much, as, 8, Women, 's,
# 		Augustine, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 8 with text:
#  		[Nair, does, n't, treat, the, issues, lightly, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 12 with text:
#  		[She, allows, each, character, to, confront, their, problems, openly, and, honestly, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 21 with text:
#  		[One, of, the, best, silly, horror, movies, of, recent, memory, ,, with, some, real, shocks, in,
# 		store, for, unwary, viewers, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 24 with text:
#  		[The, work, of, a, filmmaker, who, has, secrets, buried, at, the, heart, of, his, story, and, knows,
# 		how, to, take, time, revealing, them, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 15 with text:
#  		[Strange, occurrences, build, in, the, mind, of, the, viewer, and, take, on, extreme, urgency, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 15 with text:
#  		[Has, a, certain, ghoulish, fascination, ,, and, generates, a, fair, amount, of, B-movie,
# 		excitement, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 5 with text:
#  		[Familiar, but, utterly, delightful, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 18 with text:
#  		[A, fascinating, ,, dark, thriller, that, keeps, you, hooked, on, the, delicious, pulpiness, of,
# 		its, lurid, fiction, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 16 with text:
#  		[The, film, aims, to, be, funny, ,, uplifting, and, moving, ,, sometimes, all, at, once, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 9 with text:
#  		[The, extent, to, which, it, succeeds, is, impressive, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 16 with text:
#  		[The, film, brilliantly, shines, on, all, the, characters, ,, as, the, direction, is, intelligently,
# 		accomplished, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 35 with text:
#  		[While, not, for, every, taste, ,, this, often, very, funny, collegiate, gross-out, comedy, goes, a,
# 		long, way, toward, restoring, the, luster, of, the, National, Lampoon, film, franchise, ,, too,
# 		long, reduced, to, direct-to-video, irrelevancy, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 36 with text:
#  		[As, broad, and, cartoonish, as, the, screenplay, is, ,, there, is, an, accuracy, of, observation,
# 		in, the, work, of, the, director, ,, Frank, Novak, ,, that, keeps, the, film, grounded, in, an,
# 		undeniable, social, realism, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 35 with text:
#  		[In, addition, to, Hoffman, 's, powerful, acting, clinic, ,, this, is, that, rare, drama, that,
# 		offers, a, thoughtful, and, rewarding, glimpse, into, the, sort, of, heartache, everyone, has, felt,
# 		,, or, will, feel, someday, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 12 with text:
#  		[Jeffrey, Tambor, 's, performance, as, the, intelligent, jazz-playing, exterminator, is, Oscar-
# 		worthy, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 23 with text:
#  		[From, the, opening, strains, of, the, Average, White, Band, 's, ``, Pick, up, the, Pieces, '', ,,
# 		you, can, feel, the, love, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 19 with text:
#  		[Stevens, ', vibrant, creative, instincts, are, the, difference, between, this, and, countless,
# 		other, flicks, about, guys, and, dolls, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 24 with text:
#  		[that, it, 'll, probably, be, the, best, and, most, mature, comedy, of, the, 2002, summer, season,
# 		speaks, more, of, the, season, than, the, picture]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 34 with text:
#  		[Old, people, will, love, this, movie, ,, and, I, mean, that, in, the, nicest, possible, way, :,
# 		Last, Orders, will, touch, the, heart, of, anyone, old, enough, to, have, earned, a, 50-year,
# 		friendship, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 15 with text:
#  		[Meyjes, ', provocative, film, might, be, called, an, example, of, the, haphazardness, of, evil, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 15 with text:
#  		[Tian, emphasizes, the, isolation, of, these, characters, by, confining, color, to, Liyan, 's,
# 		backyard, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 16 with text:
#  		[The, movie, is, pretty, funny, now, and, then, without, in, any, way, demeaning, its, subjects, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 15 with text:
#  		[imagine, a, scenario, where, Bergman, approaches, Swedish, fatalism, using, Gary, Larson, 's, Far,
# 		Side, humor]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 24 with text:
#  		[Too, damn, weird, to, pass, up, ,, and, for, the, blacklight, crowd, ,, way, cheaper, -LRB-, and,
# 		better, -RRB-, than, Pink, Floyd, tickets, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 23 with text:
#  		[It, is, most, remarkable, not, because, of, its, epic, scope, ,, but, because, of, the, startling,
# 		intimacy, it, achieves, despite, that, breadth, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 8 with text:
#  		[It, 's, not, a, great, monster, movie, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 25 with text:
#  		[But, if, you, 've, paid, a, matinee, price, and, bought, a, big, tub, of, popcorn, ,, there, 's,
# 		guilty, fun, to, be, had, here, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 3 with text:
#  		[Chomp, chomp, !]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 29 with text:
#  		[The, Grey, Zone, gives, voice, to, a, story, that, needs, to, be, heard, in, the, sea, of,
# 		Holocaust, movies, ..., but, the, film, suffers, from, its, own, difficulties, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 43 with text:
#  		[Others, ,, more, attuned, to, the, anarchist, maxim, that, `, the, urge, to, destroy, is, also, a,
# 		creative, urge, ', ,, or, more, willing, to, see, with, their, own, eyes, ,, will, find, Morrison,
# 		's, iconoclastic, uses, of, technology, to, be, liberating, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 18 with text:
#  		[Miller, tells, this, very, compelling, tale, with, little, fuss, or, noise, ,, expertly, plucking,
# 		tension, from, quiet, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 15 with text:
#  		[Time, Out, is, existential, drama, without, any, of, the, pretension, associated, with, the, term,
# 		.]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 21 with text:
#  		[It, 's, a, sweet, ,, laugh-a-minute, crowd, pleaser, that, lifts, your, spirits, as, well, as, the,
# 		corners, of, your, mouth, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 30 with text:
#  		[Writer\/director, Alexander, Payne, -LRB-, Election, -RRB-, and, his, co-writer, Jim, Taylor,
# 		brilliantly, employ, their, quirky, and, fearless, ability, to, look, American, angst, in, the, eye,
# 		and, end, up, laughing, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 26 with text:
#  		[A, movie, that, at, its, best, does, n't, just, make, the, most, out, of, its, characters, ',
# 		flaws, but, insists, on, the, virtue, of, imperfection, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 13 with text:
#  		[It, 's, tough, to, watch, ,, but, it, 's, a, fantastic, movie, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 16 with text:
#  		[The, best, animated, feature, to, hit, theaters, since, Beauty, and, the, Beast, 11, years, ago, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 21 with text:
#  		[What, saves, this, deeply, affecting, film, from, being, merely, a, collection, of, wrenching,
# 		cases, is, Corcuera, 's, attention, to, detail, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 14 with text:
#  		[Pacino, is, the, best, he, 's, been, in, years, and, Keener, is, marvelous, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 13 with text:
#  		[A, solid, ,, spooky, entertainment, worthy, of, the, price, of, a, ticket, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 9 with text:
#  		[By, turns, fanciful, ,, grisly, and, engagingly, quixotic, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 7 with text:
#  		[..., very, funny, ,, very, enjoyable, ...]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 4 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 24 with text:
#  		[Adaptation, is, intricately, constructed, and, in, a, strange, way, nails, all, of, Orlean, 's,
# 		themes, without, being, a, true, adaptation, of, her, book, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 25 with text:
#  		[So, purely, enjoyable, that, you, might, not, even, notice, it, 's, a, fairly, straightforward,
# 		remake, of, Hollywood, comedies, such, as, Father, of, the, Bride, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
# ...
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 33 with text:
#  		[Returning, aggressively, to, his, formula, of, dimwitted, comedy, and, even, dimmer, characters, ,,
# 		Sandler, ,, who, also, executive, produces, ,, has, made, a, film, that, makes, previous, vehicles,
# 		look, smart, and, sassy, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 9 with text:
#  		[Exists, then, as, an, occasionally, insightful, acting, exercise, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 9 with text:
#  		[Trite, ,, banal, ,, cliched, ,, mostly, inoffensive, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 0 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 14 with text:
#  		[Mattei, is, tiresomely, grave, and, long-winded, ,, as, if, circularity, itself, indicated,
# 		profundity, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 0 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 33 with text:
#  		[It, 's, not, original, ,, and, ,, robbed, of, the, element, of, surprise, ,, it, does, n't, have,
# 		any, huge, laughs, in, its, story, of, irresponsible, cops, who, love, to, play, pranks, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 36 with text:
#  		[Whenever, its, story, is, n't, bogged, down, by, idiocy, involving, the, CIA, and, a, lost, U.S.,
# 		satellite, ,, Hunter, --, starring, Irwin, and, his, American, wife\/colleague, ,, Terri, --, is, a,
# 		movie, children, should, enjoy, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 14 with text:
#  		[It, offers, little, beyond, the, momentary, joys, of, pretty, and, weightless, intellectual,
# 		entertainment, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 11 with text:
#  		[A, sequence, of, ridiculous, shoot, -, 'em, -, up, scenes, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 23 with text:
#  		[Nothing, in, Waking, Up, in, Reno, ever, inspired, me, to, think, of, its, inhabitants, as,
# 		anything, more, than, markers, in, a, screenplay, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 0 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 8 with text:
#  		[I, 'm, just, too, bored, to, care, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 28 with text:
#  		[Irwin, is, a, man, with, enough, charisma, and, audacity, to, carry, a, dozen, films, ,, but, this,
# 		particular, result, is, ultimately, held, back, from, being, something, greater, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 19 with text:
#  		[As, befits, its, title, ,, this, PG-13-rated, piffle, is, ultimately, as, threatening, as, the,
# 		Snuggle, Fabric, Softener, bear, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 19 with text:
#  		[Attempts, by, this, ensemble, film, to, impart, a, message, are, so, heavy-handed, that, they,
# 		instead, pummel, the, audience, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 12 with text:
#  		[It, all, feels, like, a, Monty, Python, sketch, gone, horribly, wrong, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 0 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 6 with text:
#  		[Nervous, breakdowns, are, not, entertaining, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 13 with text:
#  		[Scorsese, does, n't, give, us, a, character, worth, giving, a, damn, about, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 8 with text:
#  		[A, beautifully, made, piece, of, unwatchable, drivel, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 18 with text:
#  		[Like, being, trapped, at, a, perpetual, frat, party, ..., How, can, something, so, gross, be, so,
# 		boring, ?]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 0 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 5 with text:
#  		[This, is, so, bad, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 0 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 14 with text:
#  		[Even, film, silliness, needs, a, little, gravity, ,, beyond, good, hair, and, humping, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 36 with text:
#  		[I, felt, sad, for, Lise, not, so, much, because, of, what, happens, as, because, she, was,
# 		captured, by, this, movie, when, she, obviously, belongs, in, something, lighter, and, sunnier, ,,
# 		by, Rohmer, ,, for, example, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 14 with text:
#  		[Prurient, playthings, aside, ,, there, 's, little, to, love, about, this, English, trifle, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 44 with text:
#  		[This, is, a, train, wreck, of, an, action, film, --, a, stupefying, attempt, by, the, filmmakers,
# 		to, force-feed, James, Bond, into, the, mindless, XXX, mold, and, throw, 40, years, of, cinematic,
# 		history, down, the, toilet, in, favor, of, bright, flashes, and, loud, bangs, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 21 with text:
#  		[The, film, flat, lines, when, it, should, peak, and, is, more, missed, opportunity, and, trifle,
# 		than, dark, ,, decadent, truffle, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 17 with text:
#  		[It, 's, played, in, the, most, straight-faced, fashion, ,, with, little, humor, to, lighten,
# 		things, up, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 10 with text:
#  		[The, heavy-handed, film, is, almost, laughable, as, a, consequence, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 0 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 15 with text:
#  		[Van, Wilder, brings, a, whole, new, meaning, to, the, phrase, `, comedy, gag, ., ']
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 18 with text:
#  		[At, least, one, scene, is, so, disgusting, that, viewers, may, be, hard, pressed, to, retain,
# 		their, lunch, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 21 with text:
#  		[A, disappointment, for, those, who, love, alternate, versions, of, the, Bard, ,, particularly,
# 		ones, that, involve, deep, fryers, and, hamburgers, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 16 with text:
#  		[The, film, tries, too, hard, to, be, funny, and, tries, too, hard, to, be, hip, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 10 with text:
#  		[The, end, result, is, a, film, that, 's, neither, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 20 with text:
#  		[Every, nanosecond, of, the, The, New, Guy, reminds, you, that, you, could, be, doing, something,
# 		else, far, more, pleasurable, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 6 with text:
#  		[Something, like, scrubbing, the, toilet, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 5 with text:
#  		[Or, emptying, rat, traps, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 10 with text:
#  		[Or, doing, last, year, 's, taxes, with, your, ex-wife, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 15 with text:
#  		[Scooby, Dooby, Doo, \/, And, Shaggy, too, \/, You, both, look, and, sound, great, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 3 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 25 with text:
#  		[\/, But, Daphne, ,, you, 're, too, Buff, \/, Fred, thinks, he, 's, tough, \/, And, Velma, -, wow,
# 		,, you, 've, lost, weight, !]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 21 with text:
#  		[Is, the, time, really, ripe, for, a, warmed-over, James, Bond, adventure, ,, with, a, village,
# 		idiot, as, the, 007, clone, ?]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 29 with text:
#  		[There, 's, enough, melodrama, in, this, Magnolia, Primavera, to, make, PTA, proud, yet, director,
# 		Muccino, 's, characters, are, less, worthy, of, Puccini, than, they, are, of, daytime, television,
# 		.]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 24 with text:
#  		[However, it, may, please, those, who, love, movies, that, blare, with, pop, songs, ,, young,
# 		science, fiction, fans, will, stomp, away, in, disgust, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 23 with text:
#  		[The, humor, is, n't, as, sharp, ,, the, effects, not, as, innovative, ,, nor, the, story, as,
# 		imaginative, as, in, the, original, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 0 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 7 with text:
#  		[But, it, could, have, been, worse, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 25 with text:
#  		[Some, of, their, jokes, work, ,, but, most, fail, miserably, and, in, the, end, ,, Pumpkin, is,
# 		far, more, offensive, than, it, is, funny, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 25 with text:
#  		[Even, horror, fans, will, most, likely, not, find, what, they, 're, seeking, with, Trouble, Every,
# 		Day, ;, the, movie, lacks, both, thrills, and, humor, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 0 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 20 with text:
#  		[comes, off, like, a, rejected, ABC, Afterschool, Special, ,, freshened, up, by, the, dunce, of, a,
# 		Screenwriting, 101, class, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 0 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 25 with text:
#  		[..., Designed, to, provide, a, mix, of, smiles, and, tears, ,, ``, Crossroads, '', instead,
# 		provokes, a, handful, of, unintentional, howlers, and, numerous, yawns, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 24 with text:
#  		[it, seems, to, me, the, film, is, about, the, art, of, ripping, people, off, without, ever,
# 		letting, them, consciously, know, you, have, done, so]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 32 with text:
#  		[It, 's, just, disappointingly, superficial, --, a, movie, that, has, all, the, elements, necessary,
# 		to, be, a, fascinating, ,, involving, character, study, ,, but, never, does, more, than, scratch,
# 		the, surface, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 19 with text:
#  		[The, title, not, only, describes, its, main, characters, ,, but, the, lazy, people, behind, the,
# 		camera, as, well, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 24 with text:
#  		[Sometimes, it, feels, as, if, it, might, have, been, made, in, the, '70s, or, '80s, ,, and,
# 		starred, Chevy, Chase, and, Goldie, Hawn, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 2 in namespace: 'labels'.
#
# Instance with fields:
#  	 tokens: TextField of length 28 with text:
#  		[Schaeffer, has, to, find, some, hook, on, which, to, hang, his, persistently, useless, movies, ,,
# 		and, it, might, as, well, be, the, resuscitation, of, the, middle-aged, character, .]
#  		and TokenIndexers : {'tokens': 'SingleIdTokenIndexer'}
#  	 label: LabelField with label: 1 in namespace: 'labels'.

# %%
train_path = 'data/train.txt'
dev_path = 'data/dev.txt'

sampler = BucketBatchSampler(batch_size=32, sorting_keys=["tokens"])
train_data_loader = MultiProcessDataLoader(
    reader, train_path, batch_sampler=sampler)
dev_data_loader = MultiProcessDataLoader(
    reader, dev_path, batch_sampler=sampler)
# Out:
# loading instances: 0it [00:00, ?it/s]
# loading instances: 0it [00:00, ?it/s]

# %%
vocab = Vocabulary.from_instances(chain(train_data_loader.iter_instances(), dev_data_loader.iter_instances()),
                                  min_count={'tokens': 3})
# Out:
# building vocab: 0it [00:00, ?it/s]

# %%
EMBEDDING_DIM=128

token_embedding = Embedding(
    num_embeddings=vocab.get_vocab_size('tokens'),
    embedding_dim=EMBEDDING_DIM)

# %%
HIDDEN_DIM=128

encoder = PytorchSeq2VecWrapper(
    torch.nn.LSTM(EMBEDDING_DIM, HIDDEN_DIM, batch_first=True))

# %%
@Model.register("lstm_classifier")
class LstmClassifier(Model):
    def __init__(self,
                 embedder: TextFieldEmbedder,
                 encoder: Seq2VecEncoder,
                 vocab: Vocabulary,
                 positive_label: str = '4') -> None:
        super().__init__(vocab)
        self.embedder = embedder
        self.encoder = encoder

        self.linear = torch.nn.Linear(
            in_features=encoder.get_output_dim(),
            out_features=vocab.get_vocab_size('labels'))

        positive_index = vocab.get_token_index(
            positive_label, namespace='labels')
        self.accuracy = CategoricalAccuracy()
        self.f1_measure = F1Measure(positive_index)

        self.loss_function = torch.nn.CrossEntropyLoss()

    def forward(self,
                tokens: Dict[str, torch.Tensor],
                label: torch.Tensor = None) -> torch.Tensor:
        mask = get_text_field_mask(tokens)

        embeddings = self.embedder(tokens)
        encoder_out = self.encoder(embeddings, mask)
        logits = self.linear(encoder_out)

        output = {"logits": logits}
        if label is not None:
            self.accuracy(logits, label)
            self.f1_measure(logits, label)
            output["loss"] = self.loss_function(logits, label)

        return output

    def get_metrics(self, reset: bool = False) -> Dict[str, float]:
        return {'accuracy': self.accuracy.get_metric(reset),
                **self.f1_measure.get_metric(reset)}

# %%
EMBEDDING_DIM = 128
HIDDEN_DIM = 128
 
reader = StanfordSentimentTreeBankDatasetReader()
 
train_path = 'data/train.txt'
dev_path = 'data/dev.txt'
 
sampler = BucketBatchSampler(batch_size=32, sorting_keys=["tokens"])
train_data_loader = MultiProcessDataLoader(
    reader, train_path, batch_sampler=sampler)
dev_data_loader = MultiProcessDataLoader(
    reader, dev_path, batch_sampler=sampler)
 
vocab = Vocabulary.from_instances(chain(train_data_loader.iter_instances(), 
                                        dev_data_loader.iter_instances()),
                                  min_count={'tokens': 3})
 
train_data_loader.index_with(vocab)
dev_data_loader.index_with(vocab)
 
token_embedding = Embedding(
    num_embeddings=vocab.get_vocab_size('tokens'),
    embedding_dim=EMBEDDING_DIM)
 
word_embeddings = BasicTextFieldEmbedder({"tokens": token_embedding})
 
encoder = PytorchSeq2VecWrapper(
    torch.nn.LSTM(EMBEDDING_DIM, HIDDEN_DIM, batch_first=True))
 
model = LstmClassifier(word_embeddings, encoder, vocab)
model.to(torch.device('cuda'))
 
optimizer = optim.Adam(model.parameters())
# Out:
# loading instances: 0it [00:00, ?it/s]
# loading instances: 0it [00:00, ?it/s]
# building vocab: 0it [00:00, ?it/s]

# %%
trainer = GradientDescentTrainer(
    model=model,
    optimizer=optimizer,
    data_loader=train_data_loader,
    validation_data_loader=dev_data_loader,
    patience=10,
    num_epochs=20,
    cuda_device=0)
 
trainer.train()
# Out:
#   0%|          | 0/267 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/267 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/267 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/267 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/267 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/267 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/267 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/267 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/267 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/267 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/267 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/267 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
# {'best_epoch': 1,
#  'peak_worker_0_memory_MB': 5611.02734375,
#  'peak_gpu_0_memory_MB': 25.67041015625,
#  'training_duration': '0:00:33.287449',
#  'epoch': 11,
#  'training_accuracy': 0.9405430711610487,
#  'training_precision': 0.9643140435218811,
#  'training_recall': 0.9440993666648865,
#  'training_f1': 0.9540995955467224,
#  'training_loss': 0.17581858462043637,
#  'training_worker_0_memory_MB': 5611.02734375,
#  'training_gpu_0_memory_MB': 25.66259765625,
#  'validation_accuracy': 0.3542234332425068,
#  'validation_precision': 0.35211268067359924,
#  'validation_recall': 0.4545454680919647,
#  'validation_f1': 0.3968254029750824,
#  'validation_loss': 3.6808590275900706,
#  'best_validation_accuracy': 0.3814713896457766,
#  'best_validation_precision': 0.43918919563293457,
#  'best_validation_recall': 0.39393940567970276,
#  'best_validation_f1': 0.415335476398468,
#  'best_validation_loss': 1.3965405327933176}

# %%
import os

out_dir = 'models/sent-classifier'
os.makedirs(out_dir, exist_ok=True)
path = os.path.join(out_dir)

with open(path + '/model.th', 'wb') as f:
    torch.save(model.state_dict(), f)

vocab.save_to_files(path + '/vocab')
